# %%
import neuralfoil as nf
import aerosandbox.numpy as np
import aerosandbox as asb
import aerosandbox.tools.pretty_plots as p
import matplotlib.pyplot as plt
import casadi as ca

# %%
coor_airfoil = asb.Airfoil("NACA6412")

# %%
fig, ax = plt.subplots(figsize=(6,2))
coor_airfoil.draw()

# %% [markdown]
# # Airfoil shape optimization
# Multipoint optimization.
#
# Minimize $C_{D}$ at a given Reynolds number $Re_{c} = 5e5$ by changing the airfoil's shape and angle of attack $\alpha$. We can also maintain other constraints like specifying $C_{L}, C_{M}$, trailing-edge angle, leading-edge angle, etc.

# %%
# convert xy-coordinate airfoil to KulfanAirfoil with CST parameterization
# need KulfanAirfoil to do optimization
kulfan_airfoil = coor_airfoil.to_kulfan_airfoil()
print(kulfan_airfoil.kulfan_parameters)
# Out:
# {'lower_weights': array([-1.72831249e-01, -7.31102470e-02, -1.06376274e-05,  4.68445426e-02,
#        -4.80557835e-02,  9.16088531e-02,  1.99100831e-02,  6.50767126e-02]), 'upper_weights': array([0.18418411, 0.23707142, 0.34097835, 0.30185217, 0.28409632,
#        0.34191236, 0.31573228, 0.34792275]), 'leading_edge_weight': 0.18132166489471696, 'TE_thickness': 0.002602136429121958}

# %%
# initial guess airfoil = s1223
# CL_multipoint_targets = np.array([1.4, 1.6, 1.8, 2.0, 2.2, 2.4])
CL_multipoint_targets = np.arange(1.6, 2.8, 0.2)
print(len(CL_multipoint_targets))
CL_multipoint_weights = np.array([5, 6, 7, 8, 9, 10])
# Out:
# 6

# %%
Re = 5e5 * (CL_multipoint_targets / 1.25) ** -0.5 # reynolds numbers for each target
# driving at around 50 mph = 22.4 m/s
mach = 0.065

# %%
initial_guess_airfoil = asb.KulfanAirfoil("NACA6412")
initial_guess_airfoil.name = "initial guess"

# %%
# Setting up our optimizer, initial guesses, bounds for guesses
opti = asb.Opti()

optimized_airfoil = asb.KulfanAirfoil(
    name = "Optimized",
    lower_weights=opti.variable( # weights for the lower surface of airfoil
        init_guess = initial_guess_airfoil.lower_weights,
        lower_bound = -0.25,
        upper_bound = 0.5,
    ),
    upper_weights=opti.variable(
        init_guess = initial_guess_airfoil.upper_weights,
        lower_bound = -0.25,
        upper_bound = 0.5,
    ),
    leading_edge_weight=opti.variable(
        init_guess = initial_guess_airfoil.leading_edge_weight,
        lower_bound = 1,
        upper_bound = 1
    ),
    TE_thickness=0,
)

alpha = opti.variable(
    init_guess = np.degrees(CL_multipoint_targets/(2*np.pi)),
    lower_bound = -5,
    upper_bound = 18
)

# %%
aero = optimized_airfoil.get_aero_from_neuralfoil(
    alpha=alpha,
    Re=Re,
    mach=mach,
)

# %%
# IGNORE ALL OF THIS, NEED TO BE USING AEROSANDBOX.NUMPY NOT REGULAR
## chatgpt says this is equivalent to np.diff (which doesn't work for CasAdi)
## i'm going to let chat take the wheel on this one and hope it works out
## ok it didn't work out, I commented everything out, I'm going to just take that constraint out and hope for the best
## constraint: np.diff(alpha) > 0
# diff_alpha = alpha[1:] - alpha[:-1]
# ca_diff = ca.Function("ca_diff", [alpha], [diff_alpha])

# %%
# setting up our constraints
# must optimize to within these bounds so there aren't crazy optimizations produced
# should change these constraints from the default
opti.subject_to([
    aero["analysis_confidence"] > 0.90,
    aero["CL"] == CL_multipoint_targets,
    aero["CM"] >= -0.133, # pitching moment
    np.diff(alpha) > 0,
    optimized_airfoil.local_thickness(x_over_c=0.33) >= 0.128,
    optimized_airfoil.local_thickness(x_over_c=0.90) >= 0.014,
    optimized_airfoil.TE_angle() >= 6.25,
    optimized_airfoil.lower_weights[0] < -0.05,
    optimized_airfoil.upper_weights[0] > 0.05,
    optimized_airfoil.local_thickness() > 0
])
# Out:
# [MX(fabs(opti7_lam_g_9)),
#  MX(fabs(opti7_lam_g_10)),
#  MX(fabs(opti7_lam_g_11)),
#  MX(fabs(opti7_lam_g_12)),
#  MX(fabs(opti7_lam_g_13)),
#  MX(fabs(opti7_lam_g_14)),
#  MX(fabs(opti7_lam_g_15)),
#  MX(fabs(opti7_lam_g_16)),
#  MX(fabs(opti7_lam_g_17)),
#  MX(fabs(opti7_lam_g_18))]

# %%
# what is wiggliness?? unserious name
get_wiggliness = lambda af: sum([
    np.sum(np.diff(np.diff(array)) ** 2)
    for array in [af.lower_weights, af.upper_weights]
])

# %%
opti.subject_to(
    get_wiggliness(optimized_airfoil) < 2 * get_wiggliness(initial_guess_airfoil)
)
# Out:
# MX(fabs(opti7_lam_g_19))

# %%
# doing important work here
opti.minimize(np.mean(aero["CD"] * CL_multipoint_weights))

# %%
sol = opti.solve(
    behavior_on_failure="return_last",
    options={
        "ipopt.mu_strategy": 'monotone',
        "ipopt.start_with_resto": 'yes'
    }
)
# Out:
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:      108
# Number of nonzeros in inequality constraint Jacobian.:     2043
# Number of nonzeros in Lagrangian Hessian.............:      261
#
# Total number of variables............................:       23
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        6
# Total number of inequality constraints...............:      170
#         inequality constraints with only lower bounds:      145
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       25
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.7537848e+00 4.52e+00 1.15e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1r 1.7537848e+00 4.52e+00 9.99e+02   0.7 0.00e+00    -  0.00e+00 0.00e+00R  1
#    2r 1.6442251e+00 4.11e+00 9.98e+02   0.7 3.85e+02    -  8.83e-04 1.19e-03f  1
#    3  1.6477182e+00 4.11e+00 2.25e+01  -1.0 1.19e+02    -  1.94e-02 1.16e-03h  4
#    4  1.5365926e+00 3.97e+00 3.24e+01  -1.0 6.27e+01    -  3.46e-03 3.20e-02f  1
#    5  1.5246518e+00 3.96e+00 3.23e+01  -1.0 6.69e+01  -2.0 1.67e-02 2.93e-03h  2
#    6  1.5168649e+00 3.96e+00 3.22e+01  -1.0 1.63e+02  -2.5 1.61e-02 1.49e-03h  2
#    7  1.5122290e+00 3.95e+00 3.23e+01  -1.0 8.77e+01  -2.1 2.44e-02 8.69e-04h  2
#    8  1.5058559e+00 3.95e+00 3.30e+01  -1.0 4.28e+02  -1.6 2.28e-03 6.67e-04h  3
#    9  1.4889913e+00 3.95e+00 3.58e+01  -1.0 6.77e+02  -2.1 2.15e-03 1.10e-03f  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.4414599e+00 3.94e+00 3.91e+01  -1.0 1.79e+03  -1.7 9.67e-04 7.34e-04f  1
#   11  1.3640140e+00 3.93e+00 5.05e+01  -1.0 2.38e+03  -1.3 8.10e-04 2.17e-03f  1
#   12  1.3584726e+00 3.93e+00 5.05e+01  -1.0 1.85e+03  -0.8 7.37e-04 1.21e-04h  4
#   13  1.3533057e+00 3.93e+00 5.20e+01  -1.0 1.63e+02  -0.4 9.88e-05 4.11e-04h  1
#   14  1.3522828e+00 3.93e+00 2.55e+02  -1.0 2.30e+02   0.0 1.68e-03 4.34e-05h  2
#   15  1.3387649e+00 3.93e+00 1.41e+02  -1.0 1.32e+02   0.5 2.13e-04 5.71e-04f  2
#   16  1.3327698e+00 3.93e+00 2.28e+02  -1.0 2.23e+03  -0.0 2.00e-04 2.83e-04f  2
#   17  1.3318457e+00 3.93e+00 2.53e+03  -1.0 1.91e+02   0.4 6.55e-03 1.56e-04h  3
#   18  1.2306807e+00 3.92e+00 1.81e+03  -1.0 3.48e+02  -0.1 6.08e-04 2.29e-03f  1
#   19  1.2298551e+00 3.92e+00 2.53e+03  -1.0 4.96e+02   0.4 1.39e-03 6.96e-05h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.2290134e+00 3.92e+00 2.50e+03  -1.0 6.20e+02  -0.1 4.45e-04 1.51e-04f  2
#   21  1.2126414e+00 3.92e+00 2.49e+03  -1.0 3.49e+03  -0.6 1.09e-04 6.14e-04f  2
#   22  1.1325807e+00 3.91e+00 2.50e+03  -1.0 1.80e+03  -1.1 1.92e-03 1.70e-03f  1
#   23  1.1325523e+00 3.91e+00 2.92e+03  -1.0 1.83e+03  -1.6 7.06e-04 3.58e-05h  5
#   24  1.1245711e+00 3.91e+00 2.73e+03  -1.0 5.37e+03  -2.0 5.36e-06 4.44e-04f  2
#   25  1.1154550e+00 3.91e+00 2.77e+03  -1.0 3.47e+03  -0.7 1.79e-05 3.10e-05f  5
#   26r 1.1154550e+00 3.91e+00 1.00e+03   0.6 0.00e+00    -  0.00e+00 3.87e-07R  2
#   27r 4.0260306e-01 1.38e+00 9.99e+02   0.6 3.41e+03    -  8.70e-04 2.81e-03f  1
#   28  4.0627038e-01 1.37e+00 1.07e+01  -1.0 3.97e+01    -  6.87e-04 5.31e-03f  1
#   29  3.7564233e-01 1.35e+00 1.60e+01  -1.0 4.51e+01    -  2.12e-03 9.63e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  3.8174529e-01 1.35e+00 1.61e+01  -1.0 5.14e+01    -  1.89e-02 3.48e-03h  1
#   31  3.6532567e-01 1.33e+00 1.40e+02  -1.0 8.27e+01  -0.3 1.02e-02 8.61e-03f  2
#   32  3.4887973e-01 1.33e+00 1.40e+02  -1.0 5.82e+01    -  3.04e-02 3.04e-03h  3
#   33  3.4525383e-01 1.33e+00 1.43e+02  -1.0 4.97e+01    -  2.52e-02 3.39e-03f  2
#   34  3.3511719e-01 1.32e+00 1.36e+02  -1.0 1.64e+02    -  4.38e-03 2.66e-03h  4
#   35  3.2290661e-01 1.32e+00 1.48e+02  -1.0 4.70e+02    -  4.09e-03 6.31e-04f  2
#   36  2.9873894e-01 1.31e+00 1.48e+02  -1.0 9.28e+01    -  1.06e-02 7.74e-03h  2
#   37  3.1171257e-01 1.31e+00 1.78e+02  -1.0 1.59e+02    -  9.02e-03 5.50e-03h  2
#   38  3.1485821e-01 1.31e+00 2.21e+02  -1.0 1.68e+02    -  3.59e-02 2.14e-03h  3
#   39  3.1484966e-01 1.31e+00 3.45e+02  -1.0 1.67e+02    -  2.63e-02 4.46e-05h 10
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  3.1485652e-01 1.31e+00 4.88e+02  -1.0 1.73e+02    -  2.76e-02 1.75e-05h 12
#   41  3.0723846e-01 1.30e+00 4.83e+02  -1.0 4.24e+02  -0.8 3.48e-03 5.69e-04w  1
#   42  1.0953723e+00 1.77e+00 9.72e+02  -1.0 1.77e+02    -  1.45e-02 2.73e-02w  1
#   43  1.1543074e+00 1.76e+00 1.14e+03  -1.0 2.95e+01   1.5 4.73e-03 4.04e-03w  1
#   44  3.1289820e-01 1.30e+00 4.83e+02  -1.0 1.07e+02   1.0 3.48e-03 1.42e-04h  2
#   45  3.1412908e-01 1.30e+00 6.18e+02  -1.0 1.76e+02    -  2.23e-02 9.75e-04h  6
#   46  3.1382245e-01 1.30e+00 7.22e+02  -1.0 1.56e+02    -  2.60e-02 1.12e-03h  6
#   47  3.1423149e-01 1.30e+00 2.06e+03  -1.0 1.25e+02   0.5 4.04e-02 1.22e-03h  3
#   48  3.1219381e-01 1.30e+00 2.14e+03  -1.0 2.43e+02    -  1.66e-02 8.56e-04h  4
#   49  3.1050729e-01 1.30e+00 2.45e+03  -1.0 2.11e+02    -  2.34e-02 1.23e-03h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  3.1030665e-01 1.30e+00 2.85e+03  -1.0 2.23e+02    -  1.30e-02 1.03e-03h  5
#   51  3.1104134e-01 1.30e+00 6.47e+03  -1.0 2.69e+02    -  6.18e-02 1.15e-03h  5
#   52  3.1336933e-01 1.29e+00 6.84e+03  -1.0 3.37e+02    -  2.03e-03 3.39e-04h  6
#   53r 3.1336933e-01 1.29e+00 1.00e+03   0.1 0.00e+00   0.0 0.00e+00 3.62e-07R 11
#   54r 3.2690876e-01 1.20e+00 9.98e+02   0.1 2.04e+03    -  1.76e-03 8.50e-04f  1
#   55r 2.7469425e-01 1.08e+00 9.95e+02   0.1 5.55e+02    -  1.19e-02 3.43e-03f  1
#   56  2.6062708e-01 1.08e+00 1.70e+01  -1.0 4.86e+01    -  2.49e-03 9.00e-03f  2
#   57  3.5951601e-01 1.12e+00 7.64e+01  -1.0 1.14e+03    -  1.53e-05 1.51e-03f  1
#   58  3.5064841e-01 1.12e+00 7.62e+01  -1.0 4.30e+01  -0.4 2.43e-03 1.33e-03f  2
#   59  3.3552693e-01 1.12e+00 7.56e+01  -1.0 1.07e+03    -  9.80e-06 1.72e-04f  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  3.3159057e-01 1.12e+00 7.55e+01  -1.0 6.41e+01    -  4.83e-03 5.41e-04h  4
#   61  3.2120323e-01 1.12e+00 7.56e+01  -1.0 5.58e+01    -  1.52e-02 4.30e-03f  2
#   62  3.2116797e-01 1.12e+00 7.56e+01  -1.0 5.45e+01    -  3.37e-02 1.75e-04h  4
#   63  3.2098544e-01 1.12e+00 7.56e+01  -1.0 1.09e+02    -  1.69e-03 5.11e-05h  9
#   64  3.2088743e-01 1.12e+00 7.56e+01  -1.0 1.06e+02    -  4.48e-03 2.96e-05h 10
#   65  3.2084671e-01 1.12e+00 7.56e+01  -1.0 8.57e+01    -  4.26e-03 2.20e-05h 11
#   66  3.2082249e-01 1.12e+00 7.56e+01  -1.0 9.45e+01    -  8.68e-03 2.53e-05h 11
#   67  3.2118695e-01 1.12e+00 7.56e+01  -1.0 1.10e+02    -  8.82e-03 1.03e-03h  6
#   68  3.2723014e-01 1.09e+00 7.29e+01  -1.0 1.22e+02    -  5.33e-03 1.51e-02w  1
#   69  3.2783500e-01 1.09e+00 7.41e+01  -1.0 6.75e+01    -  3.23e-02 3.00e-04w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  4.5035652e-01 1.52e+00 1.39e+03  -1.0 8.61e+01  -0.9 1.77e-03 1.50e-02w  1
#   71  3.2593867e-01 1.12e+00 7.52e+01  -1.0 1.02e+02    -  5.33e-03 3.78e-03f  2
#   72  3.3052664e-01 1.10e+00 7.46e+01  -1.0 7.14e+01    -  1.83e-02 7.00e-03f  2
#   73  3.3410276e-01 1.10e+00 7.45e+01  -1.0 6.55e+01    -  1.28e-02 1.92e-03h  5
#   74  3.3609177e-01 1.10e+00 9.96e+01  -1.0 1.06e+02    -  3.99e-02 5.12e-04h  7
#   75  3.3659453e-01 1.10e+00 1.19e+02  -1.0 2.81e+02    -  1.66e-02 5.51e-05h  8
#   76  3.3670925e-01 1.10e+00 1.83e+02  -1.0 2.62e+02    -  4.61e-02 1.33e-05h 11
#   77  3.4484273e-01 1.10e+00 1.83e+02  -1.0 2.44e+02    -  1.67e-03 1.28e-03h  5
#   78  3.4618309e-01 1.10e+00 1.86e+02  -1.0 2.26e+02    -  4.47e-03 3.03e-04h  6
#   79  3.4599630e-01 1.10e+00 1.86e+02  -1.0 6.88e+02    -  4.46e-04 6.80e-05h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80  3.4603801e-01 1.10e+00 1.93e+02  -1.0 2.38e+02  -1.4 1.32e-02 3.60e-05h  8
#   81  1.0627447e+00 1.57e+00 2.81e+03  -1.0 1.37e+02  -1.0 1.64e-02 4.04e-02w  1
#   82  1.0255110e+00 1.56e+00 2.23e+03  -1.0 7.36e+01   1.3 6.97e-04 3.55e-03w  1
#   83  1.0274136e+00 1.56e+00 2.19e+03  -1.0 3.54e+01   0.8 1.26e-02 3.28e-03w  1
#   84  3.4620941e-01 1.10e+00 2.34e+02  -1.0 1.56e+02   0.3 1.64e-02 3.94e-05h 10
#   85  3.4625736e-01 1.10e+00 3.07e+02  -1.0 7.62e+01  -0.2 1.63e-02 1.31e-05h 12
#   86r 3.4625736e-01 1.10e+00 9.99e+02   0.0 0.00e+00    -  0.00e+00 2.99e-07R 18
#   87r 3.8815734e-01 1.03e+00 9.98e+02   0.0 1.70e+03    -  3.49e-04 1.03e-03f  1
#   88r 3.4605749e-01 1.06e+00 9.94e+02   0.0 2.52e+02  -2.0 8.04e-03 3.52e-03f  1
#   89r 3.2969089e-01 1.09e+00 9.93e+02   0.0 1.11e+02   0.2 3.29e-03 1.94e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90r 3.0587815e-01 1.03e+00 9.91e+02   0.0 6.88e+01   0.7 3.88e-03 1.27e-03f  1
#   91r 2.7052615e-01 8.63e-01 9.78e+02   0.0 1.99e+01   1.1 1.84e-02 1.70e-02f  1
#   92  2.6192665e-01 8.56e-01 1.94e+02  -1.0 9.36e+00    -  8.41e-02 2.62e-02h  1
#   93  2.6387301e-01 8.52e-01 1.98e+02  -1.0 2.29e+01    -  7.32e-02 5.31e-03f  4
#   94  2.6552493e-01 8.50e-01 2.20e+02  -1.0 4.20e+01    -  3.87e-02 3.42e-03h  4
#   95  2.6545042e-01 8.48e-01 2.63e+02  -1.0 2.72e+01    -  2.64e-02 3.73e-03f  4
#   96  2.6662913e-01 8.47e-01 3.62e+02  -1.0 5.24e+01    -  2.05e-02 1.94e-03h  4
#   97  2.6839308e-01 8.46e-01 7.81e+02  -1.0 7.61e+01    -  4.56e-02 1.68e-03h  4
#   98  2.6999322e-01 8.45e-01 9.77e+02  -1.0 1.22e+02    -  9.40e-03 1.10e-03h  4
#   99  2.7335530e-01 8.43e-01 3.07e+03  -1.0 1.41e+02    -  6.30e-02 1.69e-03h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  2.7551565e-01 8.43e-01 4.08e+03  -1.0 1.97e+02    -  9.66e-03 8.71e-04h  5
#  101  2.7831673e-01 8.42e-01 1.29e+04  -1.0 2.19e+02    -  5.36e-02 9.38e-04h  5
#  102  2.8073026e-01 8.41e-01 1.83e+04  -1.0 2.46e+02    -  1.09e-02 6.46e-04h  6
#  103  3.6652251e-01 1.26e+00 1.07e+05  -1.0 2.69e+02    -  3.04e-02 1.74e-02w  1
#  104  3.6149606e-01 1.26e+00 1.07e+05  -1.0 1.05e+02   2.1 3.35e-03 1.06e-03w  1
#  105  3.3019158e-01 1.28e+00 1.23e+05  -1.0 3.74e+01   2.5 9.69e-03 8.71e-03w  1
#  106  2.8479168e-01 8.40e-01 4.12e+04  -1.0 6.13e+01   2.0 3.04e-02 1.09e-03h  4
#  107  2.8510337e-01 8.40e-01 5.68e+04  -1.0 8.30e+02    -  9.89e-03 7.25e-05h  7
#  108  2.8602994e-01 8.40e-01 1.23e+05  -1.0 5.57e+02    -  2.87e-02 2.13e-04h  6
#  109  2.8765414e-01 8.40e-01 4.43e+05  -1.0 3.29e+02    -  6.28e-02 3.49e-04h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  2.8931318e-01 8.40e-01 1.07e+06  -1.0 2.56e+02    -  3.55e-02 3.67e-04h  6
#  111  2.9001340e-01 8.39e-01 1.78e+06  -1.0 2.81e+02    -  1.81e-02 3.13e-04h  6
#  112  2.9009701e-01 8.39e-01 2.34e+06  -1.0 2.89e+02    -  9.38e-03 1.49e-04h  7
#  113  2.9043124e-01 8.39e-01 3.34e+06  -1.0 2.58e+02    -  1.31e-02 3.27e-04h  6
#  114  2.9102773e-01 8.39e-01 1.57e+07  -1.0 2.45e+02    -  1.16e-01 3.53e-04h  6
#  115  2.9218278e-01 8.38e-01 3.16e+07  -1.0 2.08e+02    -  2.85e-02 5.48e-04h  6
#  116  3.4236076e-01 1.49e+00 2.30e+08  -1.0 2.03e+02    -  3.44e-03 2.35e-02w  1
#  117  3.4201944e-01 1.49e+00 2.29e+08  -1.0 1.09e+02   4.3 6.88e-03 1.37e-03w  1
#  118  3.4252939e-01 1.49e+00 2.29e+08  -1.0 1.70e+02    -  1.98e-03 3.72e-04w  1
#  119  2.9235661e-01 8.38e-01 3.48e+07  -1.0 1.11e+02    -  3.44e-03 3.68e-04h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120  2.9332399e-01 8.38e-01 3.89e+07  -1.0 2.02e+02    -  4.27e-03 7.53e-04h  6
#  121  2.9381234e-01 8.37e-01 9.61e+07  -1.0 2.02e+02    -  4.02e-02 7.31e-04h  6
#  122  2.9378977e-01 8.37e-01 2.63e+08  -1.0 1.98e+02    -  4.44e-02 3.71e-04h  7
#  123  2.9367518e-01 8.36e-01 3.23e+08  -1.0 1.97e+02    -  6.17e-03 1.87e-04h  8
#  124  2.9353683e-01 8.36e-01 5.37e+08  -1.0 2.11e+02    -  1.79e-02 1.79e-04h  8
#  125  2.9338002e-01 8.36e-01 6.70e+08  -1.0 2.42e+02    -  6.83e-03 1.68e-04h  8
#  126  2.9321912e-01 8.36e-01 1.08e+09  -1.0 2.48e+02    -  1.69e-02 1.65e-04h  8
#  127  2.9305740e-01 8.36e-01 1.35e+09  -1.0 2.60e+02    -  6.97e-03 1.61e-04h  8
#  128  2.9289287e-01 8.36e-01 2.26e+09  -1.0 2.73e+02    -  1.92e-02 1.58e-04h  8
#  129  3.2871547e-01 5.04e+00 4.33e+09  -1.0 2.85e+02    -  6.90e-03 1.96e-02w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130  3.2696722e-01 4.99e+00 4.58e+09  -1.0 6.57e+01    -  8.67e-04 8.16e-03w  1
#  131  3.5019161e-01 4.65e+00 6.45e+09  -1.0 3.93e+01    -  8.20e-03 2.38e-02w  1
#  132  2.9273850e-01 8.36e-01 2.81e+09  -1.0 9.87e+01    -  6.90e-03 1.53e-04h  7
#  133  2.9259053e-01 8.36e-01 4.78e+09  -1.0 3.00e+02    -  2.01e-02 1.44e-04h  8
#  134  2.9245980e-01 8.35e-01 5.96e+09  -1.0 3.11e+02    -  7.18e-03 1.38e-04h  8
#  135  2.9233645e-01 8.35e-01 1.57e+10  -1.0 3.26e+02    -  4.75e-02 1.30e-04h  8
#  136  2.9224514e-01 8.35e-01 1.91e+10  -1.0 3.28e+02    -  6.32e-03 1.29e-04h  8
#  137  2.9215160e-01 8.35e-01 5.29e+10  -1.0 3.46e+02    -  5.13e-02 1.21e-04h  8
#  138  2.9206767e-01 8.35e-01 6.26e+10  -1.0 3.44e+02    -  5.62e-03 1.21e-04h  8
#  139  2.9193705e-01 8.35e-01 1.44e+11  -1.0 3.60e+02    -  4.32e-02 1.14e-04h  8
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140  2.9179226e-01 8.35e-01 1.52e+11  -1.0 3.43e+02    -  3.13e-03 5.71e-05h  9
#  141  2.9164963e-01 8.35e-01 1.88e+11  -1.0 3.57e+02    -  1.39e-02 5.64e-05h  9
#  142  5.8391495e-01 5.46e+00 1.58e+11  -1.0 3.73e+02    -  3.60e-03 1.39e-02w  1
#  143  6.3968157e-01 5.35e+00 5.32e+11  -1.0 6.85e+00  10.1 3.00e-03 1.68e-02w  1
#  144  6.3725352e-01 5.32e+00 5.30e+11  -1.0 2.45e+00  10.5 3.28e-02 4.90e-03w  1
#  145  2.9150584e-01 8.35e-01 1.97e+11  -1.0 7.88e+00  10.0 3.60e-03 5.42e-05h  8
#  146  2.9137170e-01 8.35e-01 2.27e+11  -1.0 3.91e+02    -  1.12e-02 5.17e-05h  9
#  147  2.9124423e-01 8.35e-01 2.38e+11  -1.0 4.09e+02    -  3.89e-03 4.92e-05h  9
#  148  2.9112681e-01 8.35e-01 2.65e+11  -1.0 4.30e+02    -  9.98e-03 4.67e-05h  9
#  149  2.9101765e-01 8.35e-01 2.76e+11  -1.0 4.51e+02    -  4.19e-03 4.43e-05h  9
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150  2.9091732e-01 8.35e-01 3.02e+11  -1.0 4.72e+02    -  9.06e-03 4.22e-05h  9
#  151  2.9082459e-01 8.35e-01 3.15e+11  -1.0 4.93e+02    -  4.53e-03 4.02e-05h  9
#  152  2.9073966e-01 8.35e-01 3.43e+11  -1.0 5.15e+02    -  9.64e-03 3.85e-05h  9
#  153  2.9066175e-01 8.34e-01 3.56e+11  -1.0 5.43e+02    -  4.58e-03 3.74e-05h  9
#  154  2.9059115e-01 8.34e-01 3.90e+11  -1.0 5.72e+02    -  1.13e-02 3.65e-05h  9
#  155  3.5390354e-01 4.43e+00 3.71e+11  -1.0 5.70e+02    -  4.60e-03 9.55e-03w  1
#  156  3.6892575e-01 4.39e+00 3.87e+11  -1.0 2.92e+01    -  4.12e-02 8.43e-03w  1
#  157  3.6890461e-01 4.39e+00 5.16e+11  -1.0 2.04e+01    -  1.10e-01 4.78e-05w  1
#  158  2.9052732e-01 8.34e-01 4.04e+11  -1.0 1.66e+01    -  4.60e-03 3.73e-05h  8
#  159  2.9047137e-01 8.34e-01 4.94e+11  -1.0 5.72e+02    -  2.81e-02 3.79e-05h  9
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160  2.9042392e-01 8.34e-01 5.08e+11  -1.0 4.06e+02    -  4.29e-03 5.30e-05h  9
#  161  2.9038788e-01 8.34e-01 5.73e+11  -1.0 3.66e+02    -  1.79e-02 5.73e-05h  9
#  162  2.8983950e-01 8.34e-01 5.80e+11  -1.0 2.71e+02    -  2.42e-03 1.27e-04h  8
#  163  2.8924013e-01 8.34e-01 5.87e+11  -1.0 2.56e+02    -  2.32e-03 1.36e-04h  8
#  164  2.8861911e-01 8.34e-01 5.94e+11  -1.0 2.36e+02    -  2.37e-03 1.48e-04h  8
#  165  2.8800173e-01 8.34e-01 6.02e+11  -1.0 2.14e+02    -  2.45e-03 1.58e-04h  8
#  166  2.8741411e-01 8.34e-01 6.10e+11  -1.0 2.26e+02    -  2.67e-03 1.63e-04h  8
#  167  2.8689574e-01 8.34e-01 6.69e+11  -1.0 2.51e+02    -  1.66e-02 1.55e-04h  8
#  168  2.8317649e-01 1.97e+00 6.53e+11  -1.0 8.49e+02    -  2.16e-03 5.64e-03w  1
#  169  2.8226508e-01 2.05e+00 6.50e+11  -1.0 4.42e+02    -  1.53e-03 2.54e-03w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170  2.8227679e-01 2.05e+00 7.02e+11  -1.0 6.37e+01    -  7.30e-02 8.34e-05w  1
#  171  2.8679842e-01 8.34e-01 6.76e+11  -1.0 6.05e+01    -  2.16e-03 2.20e-05h  8
#  172r 2.8679842e-01 8.34e-01 1.00e+03  -0.1 0.00e+00    -  0.00e+00 3.78e-07R 14
#  173r 2.5472482e-01 7.44e-01 1.05e+03  -0.1 2.00e+02    -  5.14e-03 2.16e-03f  1
#  174  2.5333025e-01 7.43e-01 3.19e+00  -1.0 1.66e+01    -  1.49e-02 1.74e-03h  3
#  175  2.5050438e-01 7.50e-01 1.19e+01  -1.0 2.86e+01    -  2.63e-02 4.66e-03f  2
#  176  2.4810133e-01 7.50e-01 3.79e+01  -1.0 2.70e+01    -  1.05e-01 1.47e-03h  5
#  177  2.4631771e-01 8.03e-01 1.87e+02  -1.0 4.21e+01    -  9.71e-02 9.67e-03h  3
#  178  2.4614451e-01 8.03e-01 1.88e+02  -1.0 4.72e+01    -  3.22e-02 7.14e-04h  5
#  179  2.4696429e-01 8.02e-01 3.83e+02  -1.0 4.94e+01    -  4.20e-02 8.02e-04h  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180  2.4753723e-01 8.02e-01 6.75e+02  -1.0 6.58e+01    -  4.17e-02 2.37e-04h  7
#  181  2.4777165e-01 8.02e-01 1.17e+03  -1.0 9.33e+01    -  3.52e-02 5.10e-05h 10
#  182  2.4900922e-01 8.02e-01 2.03e+03  -1.0 1.01e+02    -  3.94e-02 2.08e-04h  8
#  183  2.8248478e-01 8.05e-01 2.30e+03  -1.0 1.05e+02    -  1.15e-02 4.28e-03h  3
#  184  2.8240822e-01 8.04e-01 3.46e+06  -1.0 2.25e+00   9.6 2.89e-02 4.30e-04w  1
#  185  2.8240677e-01 8.04e-01 1.60e+09  -1.0 2.09e+00   9.1 4.48e-02 4.65e-06w  1
#  186  2.7750544e-01 8.03e-01 3.45e+09  -1.0 1.58e+01   8.6 1.49e-02 2.75e-03w  1
#  187  2.8247520e-01 8.05e-01 4.32e+05  -1.0 1.83e+01   8.1 2.89e-02 5.38e-05h  3
#  188  2.8246980e-01 8.05e-01 1.51e+07  -1.0 2.20e+00   7.7 3.58e-02 2.42e-05h  5
#  189  2.8239004e-01 8.05e-01 1.00e+08  -1.0 1.40e+01   7.2 1.66e-02 4.65e-05h  7
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190r 2.8239004e-01 8.05e-01 1.00e+03  -0.1 0.00e+00   6.7 0.00e+00 3.21e-07R 14
#  191r 2.4832832e-01 7.25e-01 9.99e+02  -0.1 8.63e+02    -  6.91e-04 1.27e-03f  1
#  192r 2.4062687e-01 7.21e-01 9.97e+02  -0.1 5.18e+02    -  5.91e-03 1.26e-03f  1
#  193  2.3971376e-01 7.22e-01 4.36e+00  -1.0 3.88e+01    -  3.08e-03 4.05e-03h  1
#  194  1.9504067e-01 7.21e-01 1.06e+02  -1.0 2.94e+01    -  8.16e-02 3.48e-02f  2
#  195  1.9550974e-01 7.09e-01 1.16e+05  -1.0 4.19e+00   6.2 4.24e-02 1.63e-02h  1
#  196  1.9551058e-01 7.09e-01 1.16e+05  -1.0 4.56e+00   5.8 7.55e-02 1.11e-04h  1
#  197  1.9544331e-01 7.07e-01 1.18e+05  -1.0 4.45e+00   5.3 2.68e-01 2.44e-03h  1
#  198  1.9080424e-01 6.78e-01 1.25e+05  -1.0 4.22e+00   4.8 1.12e-01 4.55e-02h  1
#  199  1.8354567e-01 6.63e-01 1.23e+05  -1.0 4.63e+00   4.3 5.44e-02 2.51e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200  1.8347175e-01 6.63e-01 1.23e+05  -1.0 4.84e+00   3.8 1.98e-01 4.06e-04h  1
#  201  1.8160763e-01 6.58e-01 1.23e+05  -1.0 7.26e+00   3.4 5.91e-02 7.77e-03h  1
#  202  1.8156755e-01 6.57e-01 3.07e+06  -1.0 6.99e+00   3.8 4.88e-01 1.17e-03h  1
#  203  1.8057382e-01 6.51e-01 3.07e+06  -1.0 1.29e+01   3.3 1.51e-02 9.47e-03h  1
#  204  1.8535535e-01 6.48e-01 2.47e+06  -1.0 4.13e+02    -  1.44e-02 3.55e-03h  2
#  205  1.8382509e-01 6.23e-01 2.97e+06  -1.0 7.37e+00   3.7 1.15e-01 4.39e-02h  1
#  206  1.8812485e-01 5.82e-01 1.40e+07  -1.0 5.79e+00   4.2 5.34e-01 8.56e-02h  1
#  207  1.8819100e-01 5.81e-01 2.58e+07  -1.0 1.23e+01   4.6 6.87e-02 6.11e-04h  1
#  208  1.8836174e-01 5.81e-01 2.58e+07  -1.0 1.75e+01   4.1 1.09e-03 1.01e-03h  1
#  209  1.8836538e-01 5.81e-01 4.66e+07  -1.0 1.22e+01   4.5 7.97e-02 1.78e-05h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210  1.9163794e-01 5.71e-01 4.81e+07  -1.0 1.89e+01   4.1 4.03e-02 1.98e-02f  2
#  211  1.9135573e-01 5.71e-01 4.83e+07  -1.0 1.00e+03   3.6 5.76e-06 1.25e-04f  4
#  212  1.9204966e-01 5.66e-01 4.75e+07  -1.0 2.16e+01   4.0 1.38e-06 8.41e-03f  3
#  213  1.9162979e-01 5.66e-01 4.74e+07  -1.0 1.66e+03   3.5 1.40e-04 1.25e-04f  3
#  214  1.9183039e-01 5.62e-01 4.36e+07  -1.0 2.60e+01   4.0 3.42e-02 7.32e-03h  1
#  215  1.9186408e-01 5.62e-01 3.96e+07  -1.0 2.48e+01   3.5 3.82e-02 7.15e-04h  1
#  216  1.9156006e-01 5.62e-01 3.96e+07  -1.0 1.18e+03    -  2.10e-04 2.10e-04s 10
#  217r 1.9156006e-01 5.62e-01 1.00e+03  -0.3 0.00e+00    -  0.00e+00 0.00e+00R  1
#  218r 2.2907216e-01 5.76e-01 9.99e+02  -0.3 9.44e+02    -  1.35e-03 1.59e-03f  1
#  219r 2.1867524e-01 5.57e-01 9.98e+02  -0.3 5.89e+02    -  8.84e-03 2.12e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220r 2.2513896e-01 5.34e-01 1.04e+03  -0.3 6.43e+01    -  3.87e-02 1.29e-02f  1
#  221r 2.2901579e-01 5.29e-01 1.45e+03  -0.3 1.38e+01    -  1.31e-01 4.56e-02f  1
#  222r 2.2862148e-01 5.08e-01 1.59e+03  -0.3 7.08e+00    -  3.31e-01 8.24e-02f  1
#  223r 2.2709395e-01 4.94e-01 1.34e+03  -0.3 2.29e+00    -  1.55e-01 1.70e-01h  1
#  224  2.2656388e-01 4.93e-01 2.77e+02  -1.0 1.06e+01    -  5.76e-02 7.08e-04h  1
#  225  2.2567152e-01 4.93e-01 9.67e+02  -1.0 2.90e+01    -  2.41e-02 4.92e-04h  5
#  226  2.2470548e-01 4.93e-01 4.13e+03  -1.0 4.84e+01    -  3.92e-02 5.69e-04h  5
#  227  2.2460434e-01 4.93e-01 4.70e+03  -1.0 1.17e+02    -  2.23e-03 4.56e-04h  4
#  228  2.2204943e-01 4.91e-01 4.59e+03  -1.0 9.81e+01    -  2.95e-03 3.14e-03h  1
#  229  2.2224285e-01 4.91e-01 2.48e+04  -1.0 9.23e+01    -  2.39e-02 3.07e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230  2.2313263e-01 4.91e-01 3.58e+04  -1.0 1.09e+02    -  4.55e-03 5.85e-04f  5
#  231  2.2459526e-01 4.90e-01 4.97e+05  -1.0 1.15e+02    -  7.63e-02 2.96e-03h  2
#  232  2.2422554e-01 4.90e-01 1.54e+06  -1.0 2.49e+02    -  1.49e-02 1.07e-04h  5
#  233  2.2397905e-01 4.90e-01 3.66e+06  -1.0 3.75e+02    -  1.05e-02 5.09e-05h  6
#  234r 2.2397905e-01 4.90e-01 1.00e+03  -0.3 0.00e+00    -  0.00e+00 4.78e-07R 13
#  235r 2.2936251e-01 4.95e-01 1.02e+03  -0.3 3.70e+01    -  9.81e-03 3.90e-03f  1
#  236r 2.2578234e-01 4.95e-01 1.11e+03  -0.3 1.78e+01    -  5.90e-02 1.47e-02f  1
#  237r 2.4968824e-01 5.24e-01 1.49e+03  -0.3 4.85e+00    -  1.78e-01 8.02e-02f  1
#  238r 2.4861374e-01 4.91e-01 1.34e+03  -0.3 7.45e+00    -  1.61e-02 7.95e-02f  1
#  239r 2.4536578e-01 4.80e-01 1.10e+03  -0.3 1.59e+00    -  1.97e-01 8.88e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240r 2.3369988e-01 4.61e-01 6.50e+02  -0.3 1.12e+00    -  4.19e-01 3.55e-01f  1
#  241r 2.3302193e-01 4.72e-01 5.08e+02  -0.3 5.70e-01    -  2.89e-01 5.52e-01h  1
#  242r 2.2974446e-01 4.70e-01 3.71e+02  -0.3 2.31e-01   2.0 2.56e-01 2.41e-01h  1
#  243r 2.1602460e-01 4.48e-01 3.29e+03  -0.3 4.05e-01   1.5 2.12e-01 1.00e+00h  1
#  244r 2.5335522e-01 5.07e-01 8.08e+02  -0.3 2.93e-01   1.9 8.43e-01 9.62e-01H  1
#  245r 2.4333680e-01 4.86e-01 7.21e+02  -0.3 4.24e+00    -  4.01e-02 1.12e-01f  2
#  246r 2.3425786e-01 4.21e-01 4.15e+02  -0.3 3.32e+00    -  4.56e-02 3.90e-01f  1
#  247  2.3289073e-01 4.19e-01 6.33e+00  -1.0 5.80e+00    -  2.35e-02 5.44e-03h  2
#  248  2.3074701e-01 4.18e-01 3.45e+01  -1.0 1.10e+01    -  1.90e-02 2.90e-03h  2
#  249  2.2886350e-01 4.18e-01 6.23e+01  -1.0 2.09e+01    -  6.42e-03 1.78e-03h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250  2.2777049e-01 4.18e-01 1.33e+02  -1.0 3.19e+01    -  6.90e-03 8.06e-04h  4
#  251  2.2611441e-01 4.17e-01 1.27e+02  -1.0 6.62e+01    -  6.59e-04 1.60e-03f  2
#  252  2.2467280e-01 4.16e-01 1.46e+02  -1.0 5.79e+01    -  6.13e-03 1.95e-03h  1
#  253  2.2431419e-01 4.16e-01 1.85e+02  -1.0 4.86e+01    -  4.04e-03 7.11e-04h  4
#  254  2.2410162e-01 4.16e-01 4.39e+02  -1.0 6.08e+01    -  8.52e-03 4.21e-04h  5
#  255  2.2382668e-01 4.16e-01 9.74e+02  -1.0 7.79e+01    -  1.25e-02 5.78e-04h  5
#  256  2.2366014e-01 4.16e-01 1.80e+03  -1.0 1.04e+02    -  1.26e-02 3.60e-04h  6
#  257  2.2355181e-01 4.15e-01 3.10e+03  -1.0 1.26e+02    -  1.37e-02 2.36e-04h  7
#  258  2.2348061e-01 4.15e-01 5.69e+03  -1.0 1.43e+02    -  1.99e-02 1.50e-04h  8
#  259  2.2337783e-01 4.15e-01 8.14e+03  -1.0 1.51e+02    -  1.34e-02 1.97e-04h  8
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260  2.2327812e-01 4.15e-01 1.57e+04  -1.0 1.67e+02    -  2.75e-02 1.87e-04h  8
#  261  2.2322667e-01 4.15e-01 2.36e+04  -1.0 1.78e+02    -  1.51e-02 8.72e-05h  9
#  262  2.2317462e-01 4.15e-01 4.97e+04  -1.0 1.84e+02    -  3.27e-02 8.43e-05h  9
#  263  2.2607149e-01 1.84e+00 4.30e+04  -1.0 1.84e+02    -  1.85e-02 2.19e-02w  1
#  264  2.2842712e-01 1.83e+00 2.55e+04  -1.0 1.68e+01   3.0 3.34e-03 5.39e-03w  1
#  265  2.2911279e-01 1.82e+00 5.77e+04  -1.0 1.59e+01   2.5 1.01e-03 9.62e-03w  1
#  266  2.2311571e-01 4.15e-01 7.97e+04  -1.0 2.10e+01   2.1 1.85e-02 8.56e-05h  8
#  267  2.2306595e-01 4.15e-01 2.10e+05  -1.0 2.05e+02    -  4.33e-02 7.76e-05h  9
#  268  2.2304241e-01 4.15e-01 2.70e+05  -1.0 2.20e+02    -  6.99e-03 3.79e-05h 10
#  269  2.2300871e-01 4.15e-01 6.07e+05  -1.0 2.38e+02    -  2.76e-02 6.85e-05h  9
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270  2.2299149e-01 4.15e-01 9.01e+05  -1.0 2.61e+02    -  9.71e-03 6.33e-05h  9
#  271  2.2297845e-01 4.15e-01 1.55e+06  -1.0 2.77e+02    -  1.30e-02 1.17e-04h  8
#  272  2.2298039e-01 4.15e-01 2.10e+06  -1.0 2.95e+02    -  5.70e-03 1.09e-04h  8
#  273  2.2299087e-01 4.15e-01 3.98e+06  -1.0 3.08e+02    -  1.23e-02 9.94e-05h  8
#  274  2.2300841e-01 4.15e-01 5.75e+06  -1.0 3.29e+02    -  5.87e-03 9.53e-05h  8
#  275  2.2302957e-01 4.15e-01 2.39e+07  -1.0 3.45e+02    -  3.63e-02 8.38e-05h  8
#  276  2.3235221e-01 9.39e-01 1.11e+07  -1.0 3.86e+02    -  4.41e-03 1.08e-02w  1
#  277  2.3102434e-01 9.34e-01 8.28e+07  -1.0 2.57e+01    -  1.34e-01 6.88e-03w  1
#  278  2.3326599e-01 9.37e-01 5.48e+07  -1.0 1.91e+01   5.2 3.33e-03 6.94e-03w  1
#  279  2.2304611e-01 4.15e-01 3.24e+07  -1.0 4.52e+01    -  4.41e-03 4.23e-05h  8
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  280  2.2306173e-01 4.15e-01 9.57e+07  -1.0 3.91e+02    -  2.20e-02 3.99e-05h  9
#  281  2.2308294e-01 4.15e-01 1.35e+08  -1.0 4.19e+02    -  4.73e-03 3.92e-05h  9
#  282  2.2310103e-01 4.15e-01 8.87e+08  -1.0 4.19e+02    -  5.76e-02 3.66e-05h  9
#  283  2.2313136e-01 4.15e-01 1.21e+09  -1.0 4.69e+02    -  3.95e-03 3.70e-05h  9
#  284  2.2314922e-01 4.15e-01 3.64e+09  -1.0 4.43e+02    -  1.88e-02 3.30e-05h  9
#  285  2.2317504e-01 4.15e-01 5.64e+09  -1.0 4.80e+02    -  5.10e-03 3.27e-05h  9
#  286  2.2319679e-01 4.15e-01 6.09e+10  -1.0 4.70e+02    -  8.26e-02 3.08e-05h  9
#  287  2.2321636e-01 4.15e-01 8.76e+10  -1.0 5.58e+02    -  3.82e-03 1.55e-05h 10
#  288  2.2324258e-01 4.15e-01 1.17e+12  -1.0 5.13e+02    -  1.00e-01 2.89e-05h  9
#  289  2.3727796e-01 8.26e-01 8.56e+11  -1.0 5.74e+02    -  5.35e-03 7.38e-03w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  290  2.3538142e-01 8.16e-01 1.06e+12  -1.0 1.36e+01    -  2.16e-02 1.33e-02w  1
#  291  2.3494426e-01 8.14e-01 1.93e+12  -1.0 1.51e+01    -  2.08e-02 2.81e-03w  1
#  292r 2.2324258e-01 4.15e-01 1.00e+03  -0.4 0.00e+00    -  0.00e+00 2.75e-11R 28
#  293r 2.2340019e-01 4.14e-01 9.94e+02  -0.4 7.83e+00    -  4.74e-01 5.16e-03f  1
#  294r 2.3296197e-01 4.35e-01 6.91e+02  -0.4 5.93e-01    -  2.79e-01 3.06e-01f  1
#  295r 2.3002022e-01 4.26e-01 4.63e+02  -0.4 4.87e-01    -  8.78e-01 3.29e-01f  1
#  296r 2.2347648e-01 4.19e-01 1.54e+02  -0.4 2.61e-01    -  9.64e-01 1.00e+00f  1
#  297r 2.2852127e-01 4.13e-01 8.59e+01  -0.4 2.54e-01    -  9.97e-01 1.00e+00h  1
#  298r 2.2673001e-01 4.09e-01 4.32e-01  -0.4 1.07e-01    -  1.00e+00 1.00e+00h  1
#  299r 2.2609870e-01 4.09e-01 1.12e+01  -2.7 1.33e-01    -  8.53e-01 7.93e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  300r 2.2603059e-01 4.09e-01 4.73e+01  -2.7 1.55e-01    -  5.86e-01 9.43e-01f  1
#  301r 2.2620628e-01 4.09e-01 1.86e+01  -2.7 8.76e-02    -  6.08e-01 1.00e+00f  1
#  302r 2.2626335e-01 4.09e-01 1.63e-02  -2.7 1.92e-02    -  1.00e+00 1.00e+00h  1
#  303r 2.2628839e-01 4.09e-01 4.27e-02  -4.0 1.11e-02    -  9.85e-01 1.00e+00f  1
#  304r 2.2629577e-01 4.09e-01 2.97e-04  -4.0 2.36e-03    -  1.00e+00 1.00e+00h  1
#  305r 2.2629668e-01 4.09e-01 7.48e+00  -6.0 4.34e-04    -  1.00e+00 8.85e-01f  1
#  306r 2.2629735e-01 4.09e-01 6.02e+00  -6.0 3.79e-04    -  8.78e-01 8.92e-01f  1
#  307r 2.2629743e-01 4.09e-01 2.11e+01  -6.0 4.10e-05    -  9.57e-01 1.00e+00f  1
#  308r 2.2629743e-01 4.09e-01 2.23e-11  -6.0 1.15e-08    -  1.00e+00 1.00e+00h  1
#  309r 2.2629744e-01 4.09e-01 2.14e+00  -9.0 3.95e-06    -  8.88e-01 9.12e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  310r 2.2629751e-01 4.09e-01 1.03e-01  -9.0 3.55e-05    -  9.93e-01 1.00e+00f  1
#
# Number of Iterations....: 310
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.2629750778486393e-01    2.2629750778486393e-01
# Dual infeasibility......:   1.5330180456269188e-01    1.5330180456269188e-01
# Constraint violation....:   4.0932407216334843e-01    4.0932407216334843e-01
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.7220832546270765e-10    9.7220832546270765e-10
# Overall NLP error.......:   4.0932407216334843e-01    4.0932407216334843e-01
#
#
# Number of objective function evaluations             = 1564
# Number of objective gradient evaluations             = 271
# Number of equality constraint evaluations            = 1565
# Number of inequality constraint evaluations          = 1565
# Number of equality constraint Jacobian evaluations   = 320
# Number of inequality constraint Jacobian evaluations = 320
# Number of Lagrangian Hessian evaluations             = 311
# Total seconds in IPOPT                               = 20.862
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.66 s (  1.06ms)   1.56 s (997.67us)      1564
#        nlp_g  |   1.61 s (  1.03ms)   1.61 s (  1.03ms)      1565
#   nlp_grad_f  | 589.00ms (  2.17ms) 692.61ms (  2.55ms)       272
#   nlp_hess_l  |  10.67 s ( 35.32ms)  10.74 s ( 35.55ms)       302
#    nlp_jac_g  |   5.53 s ( 17.24ms)   5.55 s ( 17.29ms)       321
#        total  |  20.86 s ( 20.86 s)  20.87 s ( 20.87 s)         1
# C:\Users\amcpo\anaconda3\Lib\site-packages\aerosandbox\optimization\opti.py:728: UserWarning: Optimization failed. Returning last solution.
#   warnings.warn("Optimization failed. Returning last solution.")

# %%
optimized_airfoil = sol(optimized_airfoil)
aero = sol(aero)

# %%
fig, ax = plt.subplots(2, 1, figsize=(7,8))

airfoils = [initial_guess_airfoil, optimized_airfoil]
colors = ['gray', 'blue']
names = ['Initial Guess = NACA6412', 'NeuralFoil Optimized 6412']

for af, color, name in zip(airfoils, colors, names):
    color = p.adjust_lightness(color, 1)
    ax[0].fill(
        af.x(), af.y(),
        facecolor=(*color, 0.09),
        edgecolor=(*color, 0.6),
        linewidth=1,
        label=name
    )

    # calls to XFoil to calculate stuff for the second graph
    aero = asb.XFoil(
        airfoil=af,
        Re=5e5,
        mach=mach,
        timeout=30,
    ).alpha(np.linspace(0, 15, 41), start_at=5)

    ax[1].plot(
        aero['CD'], aero['CL'], color=color, alpha=0.7,
        label = name
    )

ax[0].legend(fontsize=11, loc="lower right", ncol=1)
ax[0].set_title("Airfoil Shapes")
ax[0].set_xlabel("$x/c$")
ax[0].set_ylabel("$y/c$")
ax[0].axis('equal')

ax[1].legend(fontsize=11, loc="lower right", ncol=1)
ax[1].set_title("Aerodynamic Polars (analyzed with XFoil Re=500k)")
ax[1].set_xlabel("Drag Coefficient $C_D$")
ax[1].set_ylabel("Lift\nCoefficient\n$C_L$")
# p.show_plot("Comparison of NeuralFoil-optimized Airfoil and Initial S1223 Airfoil", legend=False)
p.show_plot()
